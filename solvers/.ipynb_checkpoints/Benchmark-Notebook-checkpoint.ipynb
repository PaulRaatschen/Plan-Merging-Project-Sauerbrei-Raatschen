# %% [markdown]
# # Plan-Merging-Project-Sauerbrei-Raatschen
# ## Notebook for visualising data

# %% [markdown]
# ### Setting up the project

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure

# %%
#df = pd.read_csv("./solvers/results.csv")
df = pd.read_csv("./results.csv")
solveddf = df[df['satisfied'] == True]


#allSolver = ["IS","PP","CBS-SOC","GICBS-SOC","ICBS-SOC","MCBS-SOC","MICBS-SOC","CBS-MS","GICBS-MS","ICBS-MS","MCBS-MS","MICBS-MS"]
allSolver = ["CBS-SOC","GICBS-SOC","ICBS-SOC","MCBS-SOC","MICBS-SOC","CBS-MS","GICBS-MS","ICBS-MS","MCBS-MS","MICBS-MS"]
#allSolver = ["IS","PP","CBS-SOC","GICBS-SOC"]

filterSolved = False

# %%
#Splitting data by solver 

#Dataframe of sequential planning
spdf = df[df['solver'] == 'IS']

#Dataframe of prioritized planning
ppdf = df[df['solver'] == 'PP']

#Dataframe of cbs
cbsdf = df[df['solver'] == 'CBS-SOC']

singledf= {}

for solver in allSolver:
    singledf[solver] = df[df['solver'] == solver]

# %%
#Joining data by instance

combineddf = singledf[allSolver[0]].set_index('instance').add_suffix("_"+allSolver[0])

for i in range(1,len(allSolver)):

    combineddf = combineddf.join(singledf[allSolver[i]].set_index('instance').add_suffix('_'+allSolver[i]),lsuffix="",rsuffix="")

# %% [markdown]
# ## Functions

# %%
def plotInstance(instanceName : str, df : pd.DataFrame,dataToPlot :str):
    """
    plot_Instance Plots all the results of all solvers for a specific instance

    :param instanceName: Name of the instance to analyze
    :param df: Dataframe indexed by instance
    :return: None
    """ 
    
    newdf = df.filter(like = instanceName, axis = 0)
    
    
    keyTable = []
    
    for i in allSolver:
        if(filterSolved): 
            if(newdf['satisfied'+"_"+i].item() == False):
                continue
        keyTable.append(dataToPlot+"_"+i)
    
    ax = newdf[keyTable].plot.bar(title = dataToPlot+' of all solvers')


def averageValue(instanceName : str,solverName : str, df : pd.DataFrame,dataToPlot: str, iterationNumber = -1):
    """
    plot_Instance Plots all the results of all solvers for a specific instance

    :param instanceName: Name of the instance
    :param solverName: Name of the used solver, e.g. "SP", "PP", "CBS"
    :param df: Dataframe indexed by instance
    :param iterationNumber: (Optional) number of iteration to be looked at
    :return: None
    """ 
    if iterationNumber != -1: instanceName = instanceName+str(iterationNumber)
        
    newdf = df.filter(like = instanceName, axis = 0)
    if(filterSolved): newdf = newdf[newdf['satisfied'+"_"+solverName] == True]
    
    newdf = newdf[dataToPlot+"_"+solverName]
    print(newdf)
    if newdf.size == 0:
        return 0
    
    return newdf.sum() / newdf.size

def plotScale(instanceName : str, df : pd.DataFrame, dataToPlot: str):
    """
    plot_Instance Plots all the results of all solvers for a specific instance

    :param instanceName: Name of the instance
    :param df: Dataframe indexed by instance
    :return: A list, containing for every solver a dataframe, with the avg_time per iteration
    """ 
    newdf = df.filter(like = instanceName, axis = 0)

    allResults = []
    
    for solver in allSolver:
        solverResult = pd.DataFrame(columns = ['iteration','avg_'+dataToPlot])
        numberOfIterations = len(newdf.filter(like = instanceName,axis = 0)) // len(newdf.filter(like = instanceName+"1.",axis = 0))
        for i in range(1,numberOfIterations+2):
            avg_value = averageValue(instanceName,solver, newdf,dataToPlot, iterationNumber = i)
            if(avg_value == 0): continue
            solverResult = solverResult.append(pd.DataFrame({'iteration':[i],'avg_'+dataToPlot:[avg_value]}),ignore_index=True)
        allResults.append(solverResult)
        
    ax = allResults[0].plot(x='iteration',y='avg_'+dataToPlot,label=allSolver[0])

    for dataNumber in range(1,len(allResults)):
        allResults[dataNumber].plot(ax=ax,x='iteration',y='avg_'+dataToPlot,label=allSolver[dataNumber],figsize=(15,5))
    ax.set_ylabel("Average " + dataToPlot + " value")
        
    
    return ax
    

    
    
plotInstance("X3Y3R5", combineddf,"makespan")
#print(averageValue("X3Y3R","IS", combineddf,"exec_time", iterationNumber = 1))
#filterSolved = True
#dataOfThePlot = plotScale("X5Y5R5RB",combineddf, "exec_time")
#filterSolved = False
#dataOfThePlot = plotScale("X5Y5R5RB",combineddf, "satisfied")
averageValue("X5Y5R5RB","CBS-SOC", combineddf,"satisfied")
# Out:
# instance
# X5Y5R5RB1.1     True
# X5Y5R5RB1.2     True
# X5Y5R5RB1.3     True
# X5Y5R5RB1.4     True
# X5Y5R5RB2.1     True
# X5Y5R5RB2.2     True
# X5Y5R5RB2.3     True
# X5Y5R5RB2.4     True
# X5Y5R5RB3.1     True
# X5Y5R5RB3.2     True
# X5Y5R5RB3.3     True
# X5Y5R5RB3.4     True
# X5Y5R5RB4.1     True
# X5Y5R5RB4.2     True
# X5Y5R5RB4.3     True
# X5Y5R5RB4.4    False
# X5Y5R5RB5.1    False
# X5Y5R5RB5.2     True
# X5Y5R5RB5.3     True
# X5Y5R5RB5.4     True
# X5Y5R5RB6.1     True
# X5Y5R5RB6.2     True
# X5Y5R5RB6.3     True
# X5Y5R5RB6.4     True
# X5Y5R5RB7.1     True
# X5Y5R5RB7.2     True
# X5Y5R5RB7.3     True
# X5Y5R5RB7.4    False
# X5Y5R5RB8.1     True
# X5Y5R5RB8.2     True
# X5Y5R5RB8.3     True
# X5Y5R5RB8.4     True
# Name: satisfied_CBS-SOC, dtype: bool
# 0.90625

# %%
def plotAverageInstance(instanceName, df, dataToPlot):
    filtereddf = df.filter(like = instanceName, axis = 0)
    
    newdf = pd.DataFrame({'solver':[],'avg_'+dataToPlot:[]})
    singledf[allSolver[0]].set_index('instance')
    
    for i in allSolver:
        aValue = averageValue(instanceName,i, filtereddf,dataToPlot)
        #print(i,aValue)
        newdf = newdf.append(pd.DataFrame({'solver':[i],'avg_'+dataToPlot:[aValue]}),ignore_index = True)
    newdf.set_index('solver').plot.bar()

filterSolved = True
plotAverageInstance("X5Y5R5RB",combineddf,"makespan")
# Out:
# instance
# X5Y5R5RB1.1     6.0
# X5Y5R5RB1.2     7.0
# X5Y5R5RB1.3     6.0
# X5Y5R5RB1.4     5.0
# X5Y5R5RB2.1     6.0
# X5Y5R5RB2.2     4.0
# X5Y5R5RB2.3     3.0
# X5Y5R5RB2.4     6.0
# X5Y5R5RB3.1     6.0
# X5Y5R5RB3.2     8.0
# X5Y5R5RB3.3     7.0
# X5Y5R5RB3.4     8.0
# X5Y5R5RB4.1     5.0
# X5Y5R5RB4.2     inf
# X5Y5R5RB4.3     6.0
# X5Y5R5RB5.2     9.0
# X5Y5R5RB5.3     6.0
# X5Y5R5RB5.4     4.0
# X5Y5R5RB6.1     5.0
# X5Y5R5RB6.2     5.0
# X5Y5R5RB6.3     4.0
# X5Y5R5RB6.4     8.0
# X5Y5R5RB7.1     4.0
# X5Y5R5RB7.2     inf
# X5Y5R5RB7.3     7.0
# X5Y5R5RB8.1    10.0
# X5Y5R5RB8.2     2.0
# X5Y5R5RB8.3     7.0
# X5Y5R5RB8.4     inf
# Name: makespan_CBS-SOC, dtype: float64
# instance
# X5Y5R5RB1.1     6.0
# X5Y5R5RB1.2     7.0
# X5Y5R5RB1.3     6.0
# X5Y5R5RB1.4     5.0
# X5Y5R5RB2.1     6.0
# X5Y5R5RB2.2     4.0
# X5Y5R5RB2.3     3.0
# X5Y5R5RB2.4     6.0
# X5Y5R5RB3.1     6.0
# X5Y5R5RB3.2     8.0
# X5Y5R5RB3.3     7.0
# X5Y5R5RB3.4     8.0
# X5Y5R5RB4.1     5.0
# X5Y5R5RB4.2     inf
# X5Y5R5RB4.3     6.0
# X5Y5R5RB4.4    11.0
# X5Y5R5RB5.1    11.0
# X5Y5R5RB5.2     9.0
# X5Y5R5RB5.3     6.0
# X5Y5R5RB5.4     4.0
# X5Y5R5RB6.1     5.0
# X5Y5R5RB6.2     5.0
# X5Y5R5RB6.3     6.0
# X5Y5R5RB6.4     8.0
# X5Y5R5RB7.1     4.0
# X5Y5R5RB7.2     inf
# X5Y5R5RB7.3     7.0
# X5Y5R5RB7.4     9.0
# X5Y5R5RB8.1    10.0
# X5Y5R5RB8.2     2.0
# X5Y5R5RB8.3     7.0
# X5Y5R5RB8.4     inf
# Name: makespan_GICBS-SOC, dtype: float64
# instance
# X5Y5R5RB1.1     6.0
# X5Y5R5RB1.2     7.0
# X5Y5R5RB1.3     6.0
# X5Y5R5RB1.4     5.0
# X5Y5R5RB2.1     6.0
# X5Y5R5RB2.2     4.0
# X5Y5R5RB2.3     3.0
# X5Y5R5RB2.4     6.0
# X5Y5R5RB3.1     6.0
# X5Y5R5RB3.2     8.0
# X5Y5R5RB3.3     7.0
# X5Y5R5RB3.4     8.0
# X5Y5R5RB4.1     5.0
# X5Y5R5RB4.2     inf
# X5Y5R5RB4.3     6.0
# X5Y5R5RB5.2     9.0
# X5Y5R5RB5.3     6.0
# X5Y5R5RB5.4     4.0
# X5Y5R5RB6.1     5.0
# X5Y5R5RB6.2     5.0
# X5Y5R5RB6.3     4.0
# X5Y5R5RB6.4     8.0
# X5Y5R5RB7.1     4.0
# X5Y5R5RB7.2     inf
# X5Y5R5RB7.3     7.0
# X5Y5R5RB8.1    10.0
# X5Y5R5RB8.2     2.0
# X5Y5R5RB8.3     7.0
# X5Y5R5RB8.4     inf
# Name: makespan_ICBS-SOC, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    9.0
# X5Y5R5RB3.3    6.0
# X5Y5R5RB3.4    8.0
# X5Y5R5RB4.1    5.0
# X5Y5R5RB4.2    6.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB4.4    9.0
# X5Y5R5RB5.1    9.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    6.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    4.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    5.0
# X5Y5R5RB7.3    6.0
# X5Y5R5RB7.4    9.0
# X5Y5R5RB8.1    7.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_MCBS-SOC, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    7.0
# X5Y5R5RB3.3    5.0
# X5Y5R5RB3.4    7.0
# X5Y5R5RB4.1    4.0
# X5Y5R5RB4.2    6.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB4.4    8.0
# X5Y5R5RB5.1    9.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    6.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    4.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    5.0
# X5Y5R5RB7.3    6.0
# X5Y5R5RB7.4    9.0
# X5Y5R5RB8.1    8.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_MICBS-SOC, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    7.0
# X5Y5R5RB3.3    5.0
# X5Y5R5RB3.4    7.0
# X5Y5R5RB4.1    5.0
# X5Y5R5RB4.2    7.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    5.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    5.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    inf
# X5Y5R5RB7.3    6.0
# X5Y5R5RB8.1    7.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_CBS-MS, dtype: float64
# instance
# X5Y5R5RB1.1     6.0
# X5Y5R5RB1.2     7.0
# X5Y5R5RB1.3     6.0
# X5Y5R5RB1.4     5.0
# X5Y5R5RB2.1     6.0
# X5Y5R5RB2.2     4.0
# X5Y5R5RB2.3     3.0
# X5Y5R5RB2.4     6.0
# X5Y5R5RB3.1     6.0
# X5Y5R5RB3.2     7.0
# X5Y5R5RB3.3     7.0
# X5Y5R5RB3.4     8.0
# X5Y5R5RB4.1     5.0
# X5Y5R5RB4.2     inf
# X5Y5R5RB4.3     6.0
# X5Y5R5RB4.4    11.0
# X5Y5R5RB5.1    11.0
# X5Y5R5RB5.2     7.0
# X5Y5R5RB5.3     5.0
# X5Y5R5RB5.4     4.0
# X5Y5R5RB6.1     5.0
# X5Y5R5RB6.2     5.0
# X5Y5R5RB6.3     5.0
# X5Y5R5RB6.4     6.0
# X5Y5R5RB7.1     4.0
# X5Y5R5RB7.2     7.0
# X5Y5R5RB7.3     7.0
# X5Y5R5RB7.4    12.0
# X5Y5R5RB8.1     7.0
# X5Y5R5RB8.2     2.0
# X5Y5R5RB8.3     7.0
# X5Y5R5RB8.4     5.0
# Name: makespan_GICBS-MS, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    7.0
# X5Y5R5RB3.3    5.0
# X5Y5R5RB3.4    7.0
# X5Y5R5RB4.1    5.0
# X5Y5R5RB4.2    7.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    5.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    4.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    inf
# X5Y5R5RB7.3    6.0
# X5Y5R5RB8.1    7.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_ICBS-MS, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    7.0
# X5Y5R5RB3.3    5.0
# X5Y5R5RB3.4    7.0
# X5Y5R5RB4.1    5.0
# X5Y5R5RB4.2    6.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB4.4    7.0
# X5Y5R5RB5.1    9.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    6.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    4.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    5.0
# X5Y5R5RB7.3    6.0
# X5Y5R5RB7.4    9.0
# X5Y5R5RB8.1    7.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_MCBS-MS, dtype: float64
# instance
# X5Y5R5RB1.1    6.0
# X5Y5R5RB1.2    7.0
# X5Y5R5RB1.3    6.0
# X5Y5R5RB1.4    5.0
# X5Y5R5RB2.1    6.0
# X5Y5R5RB2.2    4.0
# X5Y5R5RB2.3    3.0
# X5Y5R5RB2.4    6.0
# X5Y5R5RB3.1    6.0
# X5Y5R5RB3.2    7.0
# X5Y5R5RB3.3    5.0
# X5Y5R5RB3.4    7.0
# X5Y5R5RB4.1    4.0
# X5Y5R5RB4.2    6.0
# X5Y5R5RB4.3    6.0
# X5Y5R5RB4.4    8.0
# X5Y5R5RB5.1    9.0
# X5Y5R5RB5.2    7.0
# X5Y5R5RB5.3    6.0
# X5Y5R5RB5.4    4.0
# X5Y5R5RB6.1    5.0
# X5Y5R5RB6.2    4.0
# X5Y5R5RB6.3    4.0
# X5Y5R5RB6.4    6.0
# X5Y5R5RB7.1    4.0
# X5Y5R5RB7.2    5.0
# X5Y5R5RB7.3    7.0
# X5Y5R5RB7.4    9.0
# X5Y5R5RB8.1    7.0
# X5Y5R5RB8.2    2.0
# X5Y5R5RB8.3    7.0
# X5Y5R5RB8.4    5.0
# Name: makespan_MICBS-MS, dtype: float64

# %% [markdown]
# ### Plotting data

# %%
spdf[['instance','exec_time']].plot.bar( x = 'instance', title = 'Exec_time for sequential planning')
ppdf[['instance','exec_time']].plot.bar( x = 'instance', title = 'Exec_time for prioritized planning')
cbsdf[['instance','exec_time']].plot.bar( x = 'instance', title = 'Exec_time for cbs')
# Out:
# <AxesSubplot:title={'center':'Exec_time for cbs'}, xlabel='instance'>

# %%
combineddf[['exec_time_IS','exec_time_PP' ]].plot.bar(title = 'Exec_time of all solvers')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-80225c0eaea0> in <module>
# ----> 1 combineddf[['exec_time_IS','exec_time_PP' ]].plot.bar(title = 'Exec_time of all solvers')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['exec_time_IS', 'exec_time_PP'], dtype='object')] are in the [columns]"
